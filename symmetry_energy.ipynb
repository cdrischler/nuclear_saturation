# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from modules.plot_helpers import cm
from modules.symmetry_energy import make_sv_l_plot
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 1, figsize=(8.6*cm, 8.6*cm), constrained_layout=True)
make_sv_l_plot(axs)
fig.savefig("pdf/esym.pdf")

# %%
fig, axs = plt.subplots(1, 1, figsize=(128.6*mm/2, 75*mm), constrained_layout=True)

# make_esym_plot(axs[0])
make_sv_l_plot(axs)

fig.savefig("esym_micro-theo-only.pdf")
